# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt
import random
import pandas as pd

df = pd.read_csv(f'https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')
df.drop_duplicates(subset='#', inplace=True)
df.set_index('#', inplace=True)
df.fillna("0", inplace=True)

# %%
#Random pokemon
x = random.randint(1,649)

#Shiny rate
y = random.randint(1,10)

#Encounter rate
if y == random.randint(1,10):
    img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\shiny\{x}.png'.format(x=x))
    plt.axis('off')
    plt.imshow(img)
    print(df.loc[x]['Name'],'★')
else:
    img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\{x}.png'.format(x=x))
    plt.axis('off')
    plt.imshow(img)
    print(df.loc[x]['Name'])

#Random lvl
#lvl=random.randint(1,100)
#print(f'LVL: {lvl}\n')

#Stats lvl 1
hp= df.loc[x]['HP']
s1= df.loc[x]['Attack']
s2= df.loc[x]['Defense']
s3= df.loc[x]['Sp. Atk']
s4= df.loc[x]['Sp. Def']
s5= df.loc[x]['Speed']
t1= df.loc[x]['Type 1']
t2= df.loc[x]['Type 2']


if t2 == '0':
    print(f'Type: {t1}\n\nStats:\nHP: {hp}\nATTACK: {s1}\nDEFENSE: {s2}\nSPCL. ATTACK: {s3}\nSPCL. DEFENSE: {s4}\nSPEED: {s5}\n')
else:
    print(f'Type: {t1}/{t2}\n\nStats:\nHP: {hp}\nATTACK: {s1}\nDEFENSE: {s2}\nSPCL. ATTACK: {s3}\nSPCL. DEFENSE: {s4}\nSPEED: {s5}\n')
# Out:
# Machoke
# Type: Fighting
#
# Stats:
# HP: 80
# ATTACK: 100
# DEFENSE: 70
# SPCL. ATTACK: 50
# SPCL. DEFENSE: 60
# SPEED: 45

# %%
dex = pd.DataFrame()
teste = pd.Series([t1,t2],index=('Type1 Type2').split())
pokedex = teste.to_frame(name=df.loc[x]['Name']).T

#Capture rate
cr = random.randint(1,2)
if cr == random.randint(1,2):
    print('Gotcha!', df.loc[x]['Name'], 'was caught.')
    dex.append([teste])

else:
    print('The pokémon broke free.')
# Out:
# The pokémon broke free.

# %%
#Random pokémon team

i=1
plt.subplots(nrows=1,ncols=6,figsize=(15,20))

while i<7:
    x = random.randint(1,649)
    y = random.randint(1,10)    
    
    if y == random.randint(1,10):
        img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\shiny\{x}.png'.format(x=x))
        plt.subplot(1,6,i)
        plt.title('{name} ★'.format(name=df.loc[x]['Name']))
        plt.axis('off')
        plt.imshow(img)
        i+=1

    else:
        img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\{x}.png'.format(x=x))
        plt.subplot(1,6,i)
        plt.title(df.loc[x]['Name'])
        plt.axis('off')
        plt.imshow(img)
        i+=1

# %%
#Team effectivity

i=1
plt.subplots(nrows=1,ncols=6,figsize=(15,20))

Normal=0; Fire=0; Water=0; Electric=0; Grass=0; Ice=0; Fighting=0; Poison=0; Ground=0; Flying=0; Psychic=0; Bug=0; Rock=0; Ghost=0; Dragon=0; Dark=0; Steel=0

while i<7:
    x = random.randint(1,649)
    y = random.randint(1,10)    
    
    if y == random.randint(1,10):
        img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\shiny\{x}.png'.format(x=x))
        plt.subplot(1,6,i)
        plt.title('{name} ★'.format(name=df.loc[x]['Name']))
        plt.axis('off')
        plt.imshow(img)
        t1 = df.loc[x]['Type 1']
        t2 = df.loc[x]['Type 2']
        if t1 == 'Normal':
            Normal+=1
        if t1 == 'Fire':
            Fire+=1
        if t1 == 'Water':
            Water+=1
        if t1 == 'Electric':
            Electric+=1
        if t1 == 'Grass':
            Grass+=1
        if t1 == 'Ice':
            Ice+=1
        if t1 == 'Fighting':
            Fighting+=1
        if t1 == 'Poison':
            Poison+=1
        if t1 == 'Ground':
            Ground+=1
        if t1 == 'Flying':
            Flying+=1
        if t1 == 'Psychic':
            Psychic+=1
        if t1 == 'Bug':
            Bug+=1
        if t1 == 'Rock':
            Rock+=1
        if t1 == 'Ghost':
            Ghost+=1
        if t1 == 'Dragon':
            Dragon+=1
        if t1 == 'Dark':
            Dark+=1
        if t1 == 'Steel':
            Steel+=1
        if t2 == 'Normal':
            Normal+=1
        if t2 == 'Fire':
            Fire+=1
        if t2 == 'Water':
            Water+=1
        if t2 == 'Electric':
            Electric+=1
        if t2 == 'Grass':
            Grass+=1
        if t2 == 'Ice':
            Ice+=1
        if t2 == 'Fighting':
            Fighting+=1
        if t2 == 'Poison':
            Poison+=1
        if t2 == 'Ground':
            Ground+=1
        if t2 == 'Flying':
            Flying+=1
        if t2 == 'Psychic':
            Psychic+=1
        if t2 == 'Bug':
            Bug+=1
        if t2 == 'Rock':
            Rock+=1
        if t2 == 'Ghost':
            Ghost+=1
        if t2 == 'Dragon':
            Dragon+=1
        if t2 == 'Dark':
            Dark+=1
        if t2 == 'Steel':
            Steel+=1
        i+=1

    else:
        img = mpimg.imread(r'C:\Users\bpcar\Downloads\pokemon\main-sprites\black-white\{x}.png'.format(x=x))
        plt.subplot(1,6,i)
        plt.title(df.loc[x]['Name'])
        plt.axis('off')
        plt.imshow(img)
        t1 = df.loc[x]['Type 1']
        t2 = df.loc[x]['Type 2']
        if t1 == 'Normal':
            Normal+=1
        if t1 == 'Fire':
            Fire+=1
        if t1 == 'Water':
            Water+=1
        if t1 == 'Electric':
            Electric+=1
        if t1 == 'Grass':
            Grass+=1
        if t1 == 'Ice':
            Ice+=1
        if t1 == 'Fighting':
            Fighting+=1
        if t1 == 'Poison':
            Poison+=1
        if t1 == 'Ground':
            Ground+=1
        if t1 == 'Flying':
            Flying+=1
        if t1 == 'Psychic':
            Psychic+=1
        if t1 == 'Bug':
            Bug+=1
        if t1 == 'Rock':
            Rock+=1
        if t1 == 'Ghost':
            Ghost+=1
        if t1 == 'Dragon':
            Dragon+=1
        if t1 == 'Dark':
            Dark+=1
        if t1 == 'Steel':
            Steel+=1
        if t2 == 'Normal':
            Normal+=1
        if t2 == 'Fire':
            Fire+=1
        if t2 == 'Water':
            Water+=1
        if t2 == 'Electric':
            Electric+=1
        if t2 == 'Grass':
            Grass+=1
        if t2 == 'Ice':
            Ice+=1
        if t2 == 'Fighting':
            Fighting+=1
        if t2 == 'Poison':
            Poison+=1
        if t2 == 'Ground':
            Ground+=1
        if t2 == 'Flying':
            Flying+=1
        if t2 == 'Psychic':
            Psychic+=1
        if t2 == 'Bug':
            Bug+=1
        if t2 == 'Rock':
            Rock+=1
        if t2 == 'Ghost':
            Ghost+=1
        if t2 == 'Dragon':
            Dragon+=1
        if t2 == 'Dark':
            Dark+=1
        if t2 == 'Steel':
            Steel+=1
        i+=1
        
print('Normal',Normal,'\nFire',Fire,'\nWater',Water,'\nElectric',Electric,'\nGrass',Grass, '\nIce',Ice,'\nFighting', Fighting,'\nPoison', Poison,'\nGround', Ground,'\nFlying',Flying,'\nPsychic', Psychic,'\nBug', Bug,'\nRock', Rock,'\nGhost', Ghost,'\nDragon', Dragon,'\nDark', Dark,'\nSteel', Steel)
# Out:
# Normal 0
# Fire 0
# Water 0
# Electric 0
# Grass 1
# Ice 1
# Fighting 0
# Poison 1
# Ground 2
# Flying 0
# Psychic 1
# Bug 0
# Rock 0
# Ghost 0
# Dragon 1
# Dark 1
# Steel 2

# %%
typenamelist=['Normal', 'Fire', 'Water', 'Electric', 'Grass', 'Ice', 'Fighting', 'Poison', 'Ground', 'Flying', 'Psychic', 'Bug', 'Rock', 'Ghost', 'Dragon', 'Dark', 'Steel']
pokelist=[Normal, Fire, Water, Electric, Grass, Ice, Fighting, Poison, Ground, Flying, Psychic, Bug, Rock, Ghost, Dragon, Dark, Steel]
serie=pd.Series(pokelist,index=typenamelist)
serie.plot(kind='bar',figsize=(16,5),rot=0,width=0.8,color='darkcyan')
# Out:
# <AxesSubplot:>
